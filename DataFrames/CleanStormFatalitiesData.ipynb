# %% [markdown]
# ## Severe Weather Data Cleanup
# #### CSVs come from: https://www.ncdc.noaa.gov/data-access
#
# * 210 files total | 3 types
# * Storm Event Details
# * Storm Event Locations
# * Storm Event Fatalities
# * Dates: 1950-2019(Jan)

# %%
# Import Dependencies
import glob
import os
import pandas as pd

# %% [markdown]
# # Merging & Cleaning | StormEventsFatalities CSVs

# %%
# Reading StormEventsLocations CSVs in using glob

path = '../Resources/StormData/StormEventsFatalities'

ffiles = glob.glob(os.path.join(path, '*.csv'))

fdata = []
for ffile in ffiles:
    record = pd.read_csv(ffile)
    fdata.append(record)

# %%
# Concat CSVs into single DataFrame & check for duplicate columns
ffulldata = pd.concat(fdata, ignore_index=True)
ffulldata.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         195306        8      1800      1005317  10083307             D
# 1         195306        8      1810      1005318  10083308             D
# 2         195306        8      1908      1005319  10083310             D
# 3         195306        8      1930      1005320  10083311             D
# 4         195306        8      2000      1005321  10083312             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX FATALITY_LOCATION  \
# 0  06/08/1953 18:00:00           NaN          NaN               NaN
# 1  06/08/1953 18:10:00           NaN          NaN               NaN
# 2  06/08/1953 19:08:00           NaN          NaN               NaN
# 3  06/08/1953 19:30:00           NaN          NaN               NaN
# 4  06/08/1953 20:00:00           NaN          NaN               NaN
#
#    EVENT_YEARMONTH
# 0         195306.0
# 1         195306.0
# 2         195306.0
# 3         195306.0
# 4         195306.0

# %%
# Splitting the YEARMONTH column to get separate YEAR columns for DECADE
ffulldata['FAT_YEARMONTH1'] = ffulldata['FAT_YEARMONTH'].astype(str)
ffulldata['YEAR'] = ffulldata['FAT_YEARMONTH1'].str[0:4]
ffulldata['YEAR'] = pd.to_numeric(ffulldata.YEAR, errors='coerce')

ffulldata.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         195306        8      1800      1005317  10083307             D
# 1         195306        8      1810      1005318  10083308             D
# 2         195306        8      1908      1005319  10083310             D
# 3         195306        8      1930      1005320  10083311             D
# 4         195306        8      2000      1005321  10083312             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX FATALITY_LOCATION  \
# 0  06/08/1953 18:00:00           NaN          NaN               NaN
# 1  06/08/1953 18:10:00           NaN          NaN               NaN
# 2  06/08/1953 19:08:00           NaN          NaN               NaN
# 3  06/08/1953 19:30:00           NaN          NaN               NaN
# 4  06/08/1953 20:00:00           NaN          NaN               NaN
#
#    EVENT_YEARMONTH FAT_YEARMONTH1  YEAR
# 0         195306.0         195306  1953
# 1         195306.0         195306  1953
# 2         195306.0         195306  1953
# 3         195306.0         195306  1953
# 4         195306.0         195306  1953

# %%
# Create a new column for DECADE using binning on the YEAR column
bins = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2019]
decades = ['1950-1959', '1960-1969', '1970-1979', '1980-1989', '1990-1999', '2000-2010', '2010-2019']

ffulldata['DECADE'] = pd.cut(ffulldata['YEAR'], bins, labels=decades)
ffulldata.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         195306        8      1800      1005317  10083307             D
# 1         195306        8      1810      1005318  10083308             D
# 2         195306        8      1908      1005319  10083310             D
# 3         195306        8      1930      1005320  10083311             D
# 4         195306        8      2000      1005321  10083312             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX FATALITY_LOCATION  \
# 0  06/08/1953 18:00:00           NaN          NaN               NaN
# 1  06/08/1953 18:10:00           NaN          NaN               NaN
# 2  06/08/1953 19:08:00           NaN          NaN               NaN
# 3  06/08/1953 19:30:00           NaN          NaN               NaN
# 4  06/08/1953 20:00:00           NaN          NaN               NaN
#
#    EVENT_YEARMONTH FAT_YEARMONTH1  YEAR     DECADE
# 0         195306.0         195306  1953  1950-1959
# 1         195306.0         195306  1953  1950-1959
# 2         195306.0         195306  1953  1950-1959
# 3         195306.0         195306  1953  1950-1959
# 4         195306.0         195306  1953  1950-1959

# %%
# Rename columns
ffulldata = ffulldata.rename(columns={"FATALITY_DATE":"FATALITY_DATETIME"})

# %%
# Drop nulls in FATALITY_LOCATION column
ffulldata = ffulldata.dropna(axis=0, subset=['FATALITY_LOCATION'])
ffulldata.head()
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 560         199601        5         0      1001409   5556653             D
# 561         199601       29         0      1001275   5548075             D
# 562         199601       19         0      1001579   5569986             D
# 563         199601        1         0      1001537   5574628             D
# 564         199601       18         0      1001538   5574649             D
#
#        FATALITY_DATETIME  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION  \
# 560  01/05/1996 12:00:00          19.0            M                  Other
# 561  01/29/1996 12:00:00          75.0            F     Outside/Open Areas
# 562  01/19/1996 12:00:00          54.0            M    Mobile/Trailer Home
# 563  01/01/1996 12:00:00          37.0            M         Long Span Roof
# 564  01/18/1996 12:00:00          23.0            F  Vehicle/Towed Trailer
#
#      EVENT_YEARMONTH FAT_YEARMONTH1  YEAR     DECADE
# 560         199601.0         199601  1996  1990-1999
# 561         199601.0         199601  1996  1990-1999
# 562         199601.0         199601  1996  1990-1999
# 563         199601.0         199601  1996  1990-1999
# 564         199601.0         199601  1996  1990-1999

# %%
# Re-order columns
ffulldata = ffulldata[['EVENT_ID', 'FATALITY_ID', 'FATALITY_TYPE', 'FATALITY_AGE', 'FATALITY_SEX', 'FATALITY_LOCATION', 
                       'YEAR', 'DECADE', 'FATALITY_DATETIME']]

ffulldata.head()
# Out:
#      EVENT_ID  FATALITY_ID FATALITY_TYPE  FATALITY_AGE FATALITY_SEX  \
# 560   5556653      1001409             D          19.0            M
# 561   5548075      1001275             D          75.0            F
# 562   5569986      1001579             D          54.0            M
# 563   5574628      1001537             D          37.0            M
# 564   5574649      1001538             D          23.0            F
#
#          FATALITY_LOCATION  YEAR     DECADE    FATALITY_DATETIME
# 560                  Other  1996  1990-1999  01/05/1996 12:00:00
# 561     Outside/Open Areas  1996  1990-1999  01/29/1996 12:00:00
# 562    Mobile/Trailer Home  1996  1990-1999  01/19/1996 12:00:00
# 563         Long Span Roof  1996  1990-1999  01/01/1996 12:00:00
# 564  Vehicle/Towed Trailer  1996  1990-1999  01/18/1996 12:00:00

# %%
# Export the ffulldata as 1 CSV file
ffulldata.to_csv('../Resources/StormEventsFatalitiesALL.csv')
